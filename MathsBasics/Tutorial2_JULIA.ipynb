# %% [markdown]
# # Learning Scientific Computing using Julia
# ##Prof. Joseph Morlier
#
# https://cheatsheets.quantecon.org

# %% [markdown]
# ## 2.Vector operations (a)

# %% [markdown]
# Create the vector [1 2 3 ]. Visualize the elements. Compute V(2)*V(3) Change the third element to 4 and display the new vector on the screen.

# %%
# missing package Plots, Optim, Forwardif 
#LinearAlgebra, SparseArrays, SuiteSparse, Random, SymPy

# %%
V=[1 2 3]
# Out:
# 1×3 Array{Int64,2}:
#  1  2  3

# %%
V[1]
# Out:
# 1

# %%
V[2]*V[3]
# Out:
# 6

# %%
V[3]=4
# Out:
# 4

# %%
V
# Out:
# 1×3 Array{Int64,2}:
#  1  2  4

# %%
A = range(1, 5,
length = 100)
# Out:
# 1.0:0.04040404040404041:5.0

# %%
size(A)
# Out:
# (100,)

# %% [markdown]
# ## 2.Vector operations (b)

# %% [markdown]
# Commands : .* ./ .^ element by element algebraic operations
# Define two vectors x = [1 -2 5 3] and y = [4 1 0 -1]. Multiply x and y element by element. Compute x^2

# %%
# Define x and y 
x=[1 -2 5 3];
# Define  y 
y=[4 1 0 -1];
 
# Compute z
z = x.* y
# Out:
# 1×4 Array{Int64,2}:
#  4  -2  0  -3

# %%
x
# Out:
# 1×4 Array{Int64,2}:
#  1  -2  5  3

# %%
y
# Out:
# 1×4 Array{Int64,2}:
#  4  1  0  -1

# %%
# Compute x^2
x.^2
# Out:
# 1×4 Array{Int64,2}:
#  1  4  25  9

# %%
#compute sin(x)
sin(x)
# Out:
# DimensionMismatch("matrix is not square: dimensions are (1, 4)")
#
# Stacktrace:
#  [1] checksquare at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.5/LinearAlgebra/src/LinearAlgebra.jl:223 [inlined]
#  [2] exp!(::Array{Complex{Float64},2}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.5/LinearAlgebra/src/dense.jl:555
#  [3] sin(::Array{Int64,2}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.5/LinearAlgebra/src/dense.jl:841
#  [4] top-level scope at In[51]:2
#  [5] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
#compute sin(x)
sin.(x)
# Out:
# 1×4 Array{Float64,2}:
#  0.841471  -0.909297  -0.958924  0.14112

# %% [markdown]
# ## 3. Matrices operation (a)

# %% [markdown]
# Multiply two matrices
#
# Determine the size of the resulting matrix.

# %%
# Initialize matrices
A=[1 2; -1 3];
B=[1 0 1; 2 1 0];
# Calculate and display product of matrices 
C=A*B
# Out:
# 2×3 Array{Int64,2}:
#  5  2   1
#  5  3  -1

# %%
# Calculate and display size of new matrix
Csize = size(C)
# Out:
# (2, 3)

# %%
# Display bottom left- element and second column 
C[2,1]
# Out:
# 5

# %%
# Display second column 
C[2,:]
# Out:
# 3-element Array{Int64,1}:
#   5
#   3
#  -1

# %%
size(C[2,:])
# Out:
# (3,)

# %%
transpose(C[2,:])
# Out:
# 1×3 Transpose{Int64,Array{Int64,1}}:
#  5  3  -1

# %%
size(transpose(C[2,:]))
# Out:
# (1, 3)

# %% [markdown]
# ## 3.Matrices operation (b) Gaussian Elimination
#
# commands:
# rank : Returns the rank of a matrix
#
# inv : Returns the inverse of a matrix (squared)
#
# pinv: Returns the inverse of a matrix (rectangular)
#
# Find the rank and solution (if it exists) to the following system of equations: using LinearAlgebra

# %%
using LinearAlgebra

# %%
A = [0 7 3 ;2 8 1 ;-5 2 -9 ]
# Out:
# 3×3 Array{Int64,2}:
#   0  7   3
#   2  8   1
#  -5  2  -9

# %%
size(A)
# Out:
# (3, 3)

# %%
# Calculate and display rank of matrix
Arank = rank(A)
# Out:
# 3

# %%
#directly create transpose of b 
#1d array: size (n, )
b = [-12; 0; 26]
# Out:
# 3-element Array{Int64,1}:
#  -12
#    0
#   26

# %%
# Calculate and display inverse method
x = inv(A)*b
# Out:
# 3-element Array{Float64,1}:
#   2.0
#   1.3877787807814457e-17
#  -3.9999999999999996

# %%
# Calculate and display Gaussian elimination
x = A\b
# Out:
# 3-element Array{Float64,1}:
#   2.0
#   0.0
#  -4.0

# %% [markdown]
# ## 3.Matrices operation (c) Regression
# Let's take this example

# %%
x = [.001 .011 .13 .3 .75]*1e-2;
#The appropriate Matlab commands give (the components of x are all multiplied by 1e-2,  in order to change from cm to m)
size(x)
x=transpose(x)
# Out:
# 5×1 Transpose{Float64,Array{Float64,2}}:
#  1.0e-5
#  0.00010999999999999999
#  0.0013000000000000002
#  0.003
#  0.0075

# %%
A = [x (x).^2]
# Out:
# 5×2 Array{Float64,2}:
#  1.0e-5   1.0e-10
#  0.00011  1.21e-8
#  0.0013   1.69e-6
#  0.003    9.0e-6
#  0.0075   5.625e-5

# %%
f = [5; 50; 500; 1000; 2000]
# Out:
# 5-element Array{Int64,1}:
#     5
#    50
#   500
#  1000
#  2000

# %%
#least squares solution to this system is given by
k = A\f
# Out:
# 2-element Array{Float64,1}:
#  386389.11104512867
#      -1.599307812884773e7

# %%
k2=pinv(A)*f
# Out:
# 2-element Array{Float64,1}:
#  386389.11104512867
#      -1.5993078128847739e7

# %%
using Plots

# %%
plot(x,f, line=:stem, marker=:circle, markersize=4)

# %%
using Optim

# %%
x=0:0.1:10
# Out:
# 0.0:0.1:10.0

# %%
f3(x)=1-x.*exp(-2 * x)
# Out:
# f3 (generic function with 1 method)

# %%
plot(x,f3)

# %%
using Optim
gg(x) = (1.0 - x[1])^2 + 100.0 * (x[2] - x[1]^2)^2
# Out:
# gg (generic function with 1 method)

# %%
x0 = [0.0, 0.0]
optimize(gg, x0)
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     3.525527e-09
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    60
#     f(x) calls:    117

# %%
f2(x,y) = cos( x * y) * sin(x)
# Out:
# f2 (generic function with 1 method)

# %%
f2(1,1)
# Out:
# 0.4546487134128409

# %%
x = range(0, pi; length=21);
y = range(0, pi; length=21);

# %%
surface(x, y, f2; colorbar=false,
    xlabel="t", ylabel="x", zlabel="T",
    camera=(30, 70), color=reverse(cgrad(:RdYlBu_11)))

# %%
z = f2.(x', y) ; # .Dot Syntax for Vectorizing Functions ,note the ' which permutes the dims of x

# %%
surface(x, y, z)

# %%
f2(x) = cos( x[1] * x[2]) * sin(x[1])
# Out:
# f2 (generic function with 2 methods)

# %%
x0 = [1.5, 2]
optimize(f2, x0)
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     -1.000000e+00
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    27
#     f(x) calls:    56

# %%
optimize(f2, x0, LBFGS(); autodiff = :forward)
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     -1.000000e+00
#
#  * Found with
#     Algorithm:     L-BFGS
#
#  * Convergence measures
#     |x - x'|               = 1.85e-05 ≰ 0.0e+00
#     |x - x'|/|x'|          = 9.25e-06 ≰ 0.0e+00
#     |f(x) - f(x')|         = 8.45e-11 ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 8.45e-11 ≰ 0.0e+00
#     |g(x)|                 = 9.03e-09 ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    5
#     f(x) calls:    15
#     ∇f(x) calls:   15

# %%
x
# Out:
# 0.0:0.15707963267948966:3.141592653589793

# %% [markdown]
# ## function

# %%
#no clear function in Julia
#please rename

# %%
function ff(x) return x^2
end
ff(x) = x^2 # not anon!
# Out:
# ff (generic function with 1 method)

# %%
ff(32)
# Out:
# 1024

# %% [markdown]
# ## closure or handle in matlab

# %%
#no clear function in Julia
#erase function ff

# %%
a = 2.0
ff(x) = a + x
ff(1.0)
# Out:
# 3.0

# %% [markdown]
# ## function anonymous

# %%
f = x -> x^2
# can be rebound
# Out:
# #1 (generic function with 1 method)

# %%
f(10)
# Out:
# 100
